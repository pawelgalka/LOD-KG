# %% [markdown]
# # Agent Systems - Introduction to Cellular Automata (6 points)

# %% [markdown]
# # Cellular Automata

# %% [markdown]
# A Cellular Automata (abbreviated CA) is a *discrete, abstract computational system* ([Stanford Encyclopedia of Philospohy](https://plato.stanford.edu/entries/cellular-automata/)) used in various areas of science. Cellular Automata can simulate a wide range of processes in biology, chemistry etc. CA was invented by John von Neumann and Stanisław Ulam in the 1940s. A well-known specialist in CAs is Stephen Wolfram — creator of *Mathematica* and founder of *WolframAlpha*.
#
# ### CA elements
#
# ##### Grid
# *n*-dimensional regular and discrete grid, built of cells.
# ##### Cell
# Discrete element of the grid. Each cell can be in one of a finite number of states. All states are updated simultaneously according to the set of transition rules.
# ##### Transition rule
# A mathematical function determining the new state (time = *t*+1) according to the current state (time = *t*) of the cell and the current states of the surrounding cells.
# ##### Neighbourhood
# Cell state is updated based on the state of the surrounding cells.
# The two most popular neighbourhoods (2D) are:
# * Moore neighbourhood (8 cells):
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/8/86/CA-Moore.svg)
#
# <center>(source: <a href="https://commons.wikimedia.org/wiki/File:CA-Moore.svg">wikimedia.org</a>)</center>
#
# * von Neumann neighoburhhod (4 cells):
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/2/26/CA-von-Neumann.svg)
#
# <center>(source: <a href="https://commons.wikimedia.org/wiki/File:CA-von-Neumann.svg">wikimedia.org</a>)</center>

# %% [markdown]
# # Conway's Game of Life

# %% [markdown]
# Invented in 1970 by John Conway, Game of Life is the first and probably best-known example of Cellular Automata. The evolution of this automata is determined by its initial state (zero-player game).
#
# The game centres around an infinite, two-dimensional grid of square cells. Each cell can be in one of two possible states: alive (*1*) or dead (*0*). Each cell has 8 neighbours (Moore neighbourhood).
#
# #### Cells interact with their neighbours according to the following rules:
# * Dead cell surrounded by exactly **<span style="color:green">3</span>** living cells becomes alive.
# * Living cell remains alive if it has **<span style="color:blue">2</span>** or **<span style="color:blue">3</span>** living neighbours, otherwise it becomes dead.
#
# This set of rules can be denoted as **<span style="color:blue">23</span>/<span style="color:green">3</span>**.
#
# All states are updated at the same time (simultaneously) resulting in a new *generation*. The initial state of the grid is sometimes called a *seed*.

# %% [markdown]
# ## Patterns

# %% [markdown]
# Many interesting patterns can be observed in the game of life. Common pattern belongs to one of the three following groups:
# * still life (static) — structures that do not change between generations.
#     + block
#     + beehive
#     + pond
# * oscillators — structures that return to their initial states after a finite number of generations.
#     + beacon
#     + blinker
# * spaceships — structures that move across the grid.
#     + glider
#     + LWSS
#     + MWSS
#     + HWSS
#
# Check the patterns in the [original version](https://playgameoflife.com) of the game.
# More interesting patterns can be found in the [lexcion](https://playgameoflife.com/lexicon).

# %% [markdown]
# # Conway's Game of Life Implementation in Python (2 points)

# %% [markdown]
# Below you will find a simple implementation of Game of Life in Python. Please fill in the missing parts: rules and grid generation.
# * (1 point) Try to solve the problem with boundaries. You can start with a finite grid implementation.
# * (1 point) You can initialize the grid with any combination of cells (e.g. random or some pattern).
#
# Run your code and observe CA's behaviour (to run the animation you need to enable JavaScript). Check some popular patterns.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import itertools
from IPython.display import HTML

# %%
# %%capture
# Grid size
xSize = 40
ySize = 30

# Number of steps 
steps = 50

# Colours 
alive = 255
dead = 0

# Config
fig, ax = plt.subplots(figsize=(12,12))
plt.axis('off')

# %%
def initGrid(xSize,ySize):
    return np.random.choice([255,0], xSize*ySize, p=[0.2, 0.8]).reshape(xSize, ySize)
    
def update(frameNum, grid, im, xSize, ySize):
    im.set_data(grid)
    newGrid = grid.copy()
    # TODO Implement Conway's rules here.
    for i in range(xSize):
        for j in range(ySize):
            total = int((grid[i, (j-1)%ySize] + grid[i, (j+1)%ySize] + grid[(i-1)%xSize, j] + grid[(i+1)%xSize, j] + grid[(i-1)%xSize, (j-1)%ySize] + grid[(i-1)%xSize, (j+1)%ySize] + grid[(i+1)%xSize, (j-1)%ySize] + grid[(i+1)%xSize, (j+1)%ySize])/255)
            if grid[i, j] == 255:
                if total == 2 or total == 3:
                    continue
                else:
                    newGrid[i, j] = 0
            if grid[i, j] == 0:
                if total == 3:
                    newGrid[i,j] = 255
            
    grid[:] = newGrid[:]
    return im,

# %%
# Run simulation
grid = initGrid(xSize, ySize)
im = ax.imshow(grid)
ani = animation.FuncAnimation(fig, update, frames = steps, fargs = [grid, im,xSize, ySize])

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge2165de25c8542f1a99fa03d2861153d">
#   <div class="anim-controls">
#     <input id="_anim_slidere2165de25c8542f1a99fa03d2861153d" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime2165de25c8542f1a99fa03d2861153d.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime2165de25c8542f1a99fa03d2861153d.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime2165de25c8542f1a99fa03d2861153d.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime2165de25c8542f1a99fa03d2861153d.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime2165de25c8542f1a99fa03d2861153d.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime2165de25c8542f1a99fa03d2861153d.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime2165de25c8542f1a99fa03d2861153d.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime2165de25c8542f1a99fa03d2861153d.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime2165de25c8542f1a99fa03d2861153d.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime2165de25c8542f1a99fa03d2861153d.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte2165de25c8542f1a99fa03d2861153d"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e2165de25c8542f1a99fa03d2861153d"
#              >
#       <label for="_anim_radio1_e2165de25c8542f1a99fa03d2861153d">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e2165de25c8542f1a99fa03d2861153d"
#              checked>
#       <label for="_anim_radio2_e2165de25c8542f1a99fa03d2861153d">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e2165de25c8542f1a99fa03d2861153d"
#              >
#       <label for="_anim_radio3_e2165de25c8542f1a99fa03d2861153d">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge2165de25c8542f1a99fa03d2861153d";
#     var slider_id = "_anim_slidere2165de25c8542f1a99fa03d2861153d";
#     var loop_select_id = "_anim_loop_selecte2165de25c8542f1a99fa03d2861153d";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# # Alternative Rules (2 points)

# %% [markdown]
# Change the transition rules. Try to implement periodic boundaries. Please implement the following rules:
# * Cities — 2345/45678 (1 point).
# * Coral — 45678/3 (1 point).
#
# Try to find other interesting rules.

# %%
def updateCities(frameNum, grid, im, xSize, ySize):
    im.set_data(grid)
    newGrid = grid.copy()
    # TODO Implement Conway's rules here.
    for i in range(xSize):
        for j in range(ySize):
            total = int((grid[i, (j-1)%ySize] + grid[i, (j+1)%ySize] + grid[(i-1)%xSize, j] + grid[(i+1)%xSize, j] + grid[(i-1)%xSize, (j-1)%ySize] + grid[(i-1)%xSize, (j+1)%ySize] + grid[(i+1)%xSize, (j-1)%ySize] + grid[(i+1)%xSize, (j+1)%ySize])/255)
            if grid[i, j] == 255:
                if total == 2 or total == 3 or total == 4 or total == 5:
                    continue
                else:
                    newGrid[i, j] = 0
            if grid[i, j] == 0:
                if total == 4 or total == 5 or total == 6 or total == 7 or total == 8:
                    newGrid[i,j] = 255
            
    grid[:] = newGrid[:]
    return im,

def updateCoral(frameNum, grid, im, xSize, ySize):
    im.set_data(grid)
    newGrid = grid.copy()
    # TODO Implement Conway's rules here.
    for i in range(xSize):
        for j in range(ySize):
            total = int((grid[i, (j-1)%ySize] + grid[i, (j+1)%ySize] + grid[(i-1)%xSize, j] + grid[(i+1)%xSize, j] + grid[(i-1)%xSize, (j-1)%ySize] + grid[(i-1)%xSize, (j+1)%ySize] + grid[(i+1)%xSize, (j-1)%ySize] + grid[(i+1)%xSize, (j+1)%ySize])/255)
            if grid[i, j] == 255:
                if total == 4 or total == 5 or total == 6 or total == 7 or total == 8:
                    continue
                else:
                    newGrid[i, j] = 0
            if grid[i, j] == 0:
                if total == 3:
                    newGrid[i,j] = 255
            
    grid[:] = newGrid[:]
    return im,

# %%
# Run simulation
grid = initGrid(xSize, ySize)
im = ax.imshow(grid)
ani = animation.FuncAnimation(fig, updateCities, frames = steps, fargs = [grid, im,xSize, ySize])

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge700519e41274c96ad17520bedcbccb8">
#   <div class="anim-controls">
#     <input id="_anim_slidere700519e41274c96ad17520bedcbccb8" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime700519e41274c96ad17520bedcbccb8.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime700519e41274c96ad17520bedcbccb8.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime700519e41274c96ad17520bedcbccb8.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime700519e41274c96ad17520bedcbccb8.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime700519e41274c96ad17520bedcbccb8.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime700519e41274c96ad17520bedcbccb8.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime700519e41274c96ad17520bedcbccb8.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime700519e41274c96ad17520bedcbccb8.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime700519e41274c96ad17520bedcbccb8.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime700519e41274c96ad17520bedcbccb8.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte700519e41274c96ad17520bedcbccb8"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e700519e41274c96ad17520bedcbccb8"
#              >
#       <label for="_anim_radio1_e700519e41274c96ad17520bedcbccb8">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e700519e41274c96ad17520bedcbccb8"
#              checked>
#       <label for="_anim_radio2_e700519e41274c96ad17520bedcbccb8">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e700519e41274c96ad17520bedcbccb8"
#              >
#       <label for="_anim_radio3_e700519e41274c96ad17520bedcbccb8">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge700519e41274c96ad17520bedcbccb8";
#     var slider_id = "_anim_slidere700519e41274c96ad17520bedcbccb8";
#     var loop_select_id = "_anim_loop_selecte700519e41274c96ad17520bedcbccb8";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %%
# Run simulation
grid = initGrid(xSize, ySize)
im = ax.imshow(grid)
ani = animation.FuncAnimation(fig, updateCoral, frames = steps, fargs = [grid, im,xSize, ySize])

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgaed85f1558cb4745bbad3a87729ad955">
#   <div class="anim-controls">
#     <input id="_anim_slideraed85f1558cb4745bbad3a87729ad955" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animaed85f1558cb4745bbad3a87729ad955.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animaed85f1558cb4745bbad3a87729ad955.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animaed85f1558cb4745bbad3a87729ad955.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animaed85f1558cb4745bbad3a87729ad955.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animaed85f1558cb4745bbad3a87729ad955.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animaed85f1558cb4745bbad3a87729ad955.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animaed85f1558cb4745bbad3a87729ad955.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animaed85f1558cb4745bbad3a87729ad955.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animaed85f1558cb4745bbad3a87729ad955.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animaed85f1558cb4745bbad3a87729ad955.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectaed85f1558cb4745bbad3a87729ad955"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_aed85f1558cb4745bbad3a87729ad955"
#              >
#       <label for="_anim_radio1_aed85f1558cb4745bbad3a87729ad955">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_aed85f1558cb4745bbad3a87729ad955"
#              checked>
#       <label for="_anim_radio2_aed85f1558cb4745bbad3a87729ad955">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_aed85f1558cb4745bbad3a87729ad955"
#              >
#       <label for="_anim_radio3_aed85f1558cb4745bbad3a87729ad955">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgaed85f1558cb4745bbad3a87729ad955";
#     var slider_id = "_anim_slideraed85f1558cb4745bbad3a87729ad955";
#     var loop_select_id = "_anim_loop_selectaed85f1558cb4745bbad3a87729ad955";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# # Rain (2 points)

# %% [markdown]
# Create a CA simulation of the rain:
# 1. Change the neighbourhood definition. In this simulation, each cell will have only one neighbour — the cell located directly over the given cell.
# 2. Create a function that will randomly (with low probability e.g. 5%) change the values in the first row of the grid to 6. Call this function in each *update* call.
# 3. Implement the following transition rules:
#     * If the current cell state is higher than 0, decrease the state by 1,
#     * If the current cell state is 0 and the neighbouring cell's state is greater than 0, change the next state to 6.

# %%
# %%capture
# Grid size
xSize = 30
ySize = 80

# Number of steps 
steps = 50 

# Config
fig, ax = plt.subplots()
plt.axis('off')

# %%
def changeTheFirstRow(grid):
    grid[0,:] = np.random.choice([6, 0], len(grid[0]), p=[0.05, 0.95])
    return grid

def initGrid(xSize,ySize):
    data = np.zeros((xSize, ySize))
    return changeTheFirstRow(data)
    
    
def update(frameNum, grid, im, xSize, ySize):
    im.set_data(grid)
    newGrid = grid.copy()
    for i in range(1,xSize):
        for j in range(ySize):
            if grid[i,j] > 0:
                newGrid[i,j]-=1
            else:
                if grid[i-1,j] > 0:
                    newGrid[i,j]=6
 
    
    grid[:] = newGrid[:]
    changeTheFirstRow(grid)
    return im,

# %%
# Run simulation
grid = initGrid(xSize, ySize)
im = ax.imshow(grid)
ani = animation.FuncAnimation(fig, update, frames = steps, fargs = [grid, im,xSize, ySize])

HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb4f92bcb078d4cf9baa492806708e312">
#   <div class="anim-controls">
#     <input id="_anim_sliderb4f92bcb078d4cf9baa492806708e312" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb4f92bcb078d4cf9baa492806708e312.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animb4f92bcb078d4cf9baa492806708e312.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animb4f92bcb078d4cf9baa492806708e312.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animb4f92bcb078d4cf9baa492806708e312.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animb4f92bcb078d4cf9baa492806708e312.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animb4f92bcb078d4cf9baa492806708e312.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animb4f92bcb078d4cf9baa492806708e312.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animb4f92bcb078d4cf9baa492806708e312.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animb4f92bcb078d4cf9baa492806708e312.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animb4f92bcb078d4cf9baa492806708e312.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectb4f92bcb078d4cf9baa492806708e312"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b4f92bcb078d4cf9baa492806708e312"
#              >
#       <label for="_anim_radio1_b4f92bcb078d4cf9baa492806708e312">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b4f92bcb078d4cf9baa492806708e312"
#              checked>
#       <label for="_anim_radio2_b4f92bcb078d4cf9baa492806708e312">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b4f92bcb078d4cf9baa492806708e312"
#              >
#       <label for="_anim_radio3_b4f92bcb078d4cf9baa492806708e312">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb4f92bcb078d4cf9baa492806708e312";
#     var slider_id = "_anim_sliderb4f92bcb078d4cf9baa492806708e312";
#     var loop_select_id = "_anim_loop_selectb4f92bcb078d4cf9baa492806708e312";
#     var frames = new Array(50);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA
